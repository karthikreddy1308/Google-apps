# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
fileapp= '/content/drive/MyDrive/googleplaystore.csv'
fileuserreviews= '/content/drive/MyDrive/googleplaystore_user_reviews.csv'

# %%
dfapps=pd.read_csv(fileapp)
dfreviews=pd.read_csv(fileuserreviews)

# %%
dfapps.info
# Out:
# <bound method DataFrame.info of                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
dfapps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
dfapps.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Fill missing 'Rating' values with the mean rating
dfapps['Rating'].fillna(dfapps['Rating'].mean(), inplace=True)

# Drop rows with missing values in 'Type', 'Content Rating', 'Current Ver', and 'Android Ver'
columns_to_drop_na = ['Type', 'Content Rating', 'Current Ver', 'Android Ver']
dfapps.dropna(subset=columns_to_drop_na, inplace=True)

# Check if there are still missing values
print(dfapps.isnull().sum())
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64
# <ipython-input-7-45a3a203281d>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dfapps['Rating'].fillna(dfapps['Rating'].mean(), inplace=True)

# %%
dfapps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
print(dfapps.dtypes)
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
# Convert 'Reviews' to integer
dfapps['Reviews'] = dfapps['Reviews'].astype(int)

# %%
print(dfapps['Installs'].dtype)
# Out:
# object

# %%
dfapps['Installs'] = dfapps['Installs'].astype(str)

# %%
# Remove '+' and ',' and convert 'Installs' to integer
dfapps['Installs'] = (
    dfapps['Installs']
    .str.replace(',', '', regex=False)
    .str.replace('+', '', regex=False)
    .astype(int)
)

# %%
print(dfapps['Installs'].head())
# Out:
# 0       10000
# 1      500000
# 2     5000000
# 3    50000000
# 4      100000
# Name: Installs, dtype: int64

# %%
# Remove '$' and convert 'Price' to float
dfapps['Price'] = (
    dfapps['Price']
    .str.replace('$', '', regex=False)
    .astype(float)
)

# %%
# Function to convert sizes to bytes
def convert_size(size):
    if 'M' in size:
        return float(size.replace('M', '')) * 1e6
    elif 'k' in size:
        return float(size.replace('k', '')) * 1e3
    elif size == 'Varies with device':
        return None  # Handle "Varies with device" as missing value
    else:
        return None  # Handle unexpected values as missing

# Apply the conversion function to 'Size' column
dfapps['Size'] = dfapps['Size'].apply(convert_size)

# %%
# Check data types and summary statistics
print(dfapps.dtypes)
print(dfapps[['Reviews', 'Installs', 'Price', 'Size']].describe())
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs            int64
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object
#             Reviews      Installs         Price          Size
# count  1.082900e+04  1.082900e+04  10829.000000  9.135000e+03
# mean   4.446018e+05  1.547990e+07      1.028091  2.153496e+07
# std    2.929213e+06  8.507114e+07     15.957778  2.259366e+07
# min    0.000000e+00  0.000000e+00      0.000000  8.500000e+03
# 25%    3.800000e+01  5.000000e+03      0.000000  4.900000e+06
# 50%    2.100000e+03  1.000000e+05      0.000000  1.300000e+07
# 75%    5.481500e+04  5.000000e+06      0.000000  3.000000e+07
# max    7.815831e+07  1.000000e+09    400.000000  1.000000e+08

# %%
top_installed_apps = dfapps[['App', 'Installs']].sort_values(by='Installs', ascending=False).head(10)
print(top_installed_apps)
# Out:
#                                            App    Installs
# 391              Skype - free IM & video calls  1000000000
# 1872                            Subway Surfers  1000000000
# 4104  Messenger – Text and Video Chat for Free  1000000000
# 3736                               Google News  1000000000
# 3687                   Google Play Movies & TV  1000000000
# 3665                                   YouTube  1000000000
# 2611                                 Instagram  1000000000
# 3565                              Google Drive  1000000000
# 5395                             Google Photos  1000000000
# 2604                                 Instagram  1000000000

# %% [markdown]
# There are duplicate entries over here like Instagram. We need to remove the duplicate entries first

# %%
#identify duplicates
duplicates = dfapps[dfapps.duplicated(subset='App', keep=False)]
print(duplicates)
# Out:
#                                                   App             Category  \
# 1                                 Coloring book moana       ART_AND_DESIGN
# 23                             Mcqueen Coloring pages       ART_AND_DESIGN
# 36     UNICORN - Color By Number & Pixel Art Coloring       ART_AND_DESIGN
# 42                         Textgram - write on photos       ART_AND_DESIGN
# 139                              Wattpad 📖 Free Books  BOOKS_AND_REFERENCE
# ...                                               ...                  ...
# 10715                              FarmersOnly Dating               DATING
# 10720              Firefox Focus: The privacy browser        COMMUNICATION
# 10730                                     FP Notebook              MEDICAL
# 10753                  Slickdeals: Coupons & Shopping             SHOPPING
# 10768                                            AAFP              MEDICAL
#
# ...

# %%
dfapps = dfapps.sort_values(by='Rating', ascending=False).drop_duplicates(subset='App', keep='first')
dfapps = dfapps.drop_duplicates(subset='App', keep='first')
print(dfapps['App'].duplicated().any())
# Out:
# False

# %%
top_installed_apps = dfapps[['App', 'Installs']].sort_values(by='Installs', ascending=False).head(10)
print(top_installed_apps)
# Out:
#                                 App    Installs
# 152               Google Play Books  1000000000
# 3816                    Google News  1000000000
# 3117      Maps - Navigate & Explore  1000000000
# 468   Skype - free IM & video calls  1000000000
# 3687        Google Play Movies & TV  1000000000
# 451                           Gmail  1000000000
# 3904             WhatsApp Messenger  1000000000
# 2884                  Google Photos  1000000000
# 4144                        Google+  1000000000
# 3232             Google Street View  1000000000

# %%
installs_by_category = (
    dfapps.groupby('Category')['Installs']
    .sum()
    .sort_values(ascending=False)
)
print(installs_by_category)
# Out:
# Category
# GAME                   12072924415
# COMMUNICATION          11038276251
# TOOLS                   8101271905
# FAMILY                  7483881405
# PRODUCTIVITY            5793091369
# SOCIAL                  5487867902
# PHOTOGRAPHY             4649147655
# VIDEO_PLAYERS           3931902720
# TRAVEL_AND_LOCAL        2894887146
# NEWS_AND_MAGAZINES      2369217760
# BOOKS_AND_REFERENCE     1665968576
# PERSONALIZATION         1532483782
# SHOPPING                1400348785
# SPORTS                  1196474498
# HEALTH_AND_FITNESS      1134022512
# ENTERTAINMENT            920160000
# BUSINESS                 697164865
# LIFESTYLE                503823539
# MAPS_AND_NAVIGATION      503281890
# FINANCE                  455348734
# WEATHER                  361100520
# EDUCATION                231952000
# FOOD_AND_DRINK           211798751
# DATING                   140925107
# ART_AND_DESIGN           113833100
# HOUSE_AND_HOME            97212461
# ...

# %%
import matplotlib.pyplot as plt

installs_by_category.plot(kind='bar', figsize=(12, 6), title='Total Installs by Category', color='skyblue')
plt.ylabel('Total Installs')
plt.xlabel('Category')
plt.show()

# %%
correlation_matrix = dfapps[['Installs', 'Reviews', 'Rating', 'Price']].corr()

import seaborn as sns
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Strong Positive Correlation Between Installs and Reviews (0.63):
#
# Apps with more installs tend to have more reviews. This is logical, as a larger user base generally generates more feedback.
# Weak Positive Correlation Between Rating and Other Variables (0.039 to 0.054):
#
# Ratings show a minimal positive correlation with installs and reviews, indicating that user satisfaction (as reflected by ratings) is not strongly tied to the popularity of the app or the number of reviews.
# No Significant Correlation Between Price and Other Variables:
#
# The near-zero correlations between price and installs (-0.0094), reviews (-0.0076), and ratings (-0.019) suggest that pricing does not significantly affect the number of
#  installs, reviews, or user satisfaction.
# Installs as a Key Metric:
#
# The moderate positive correlation between installs and reviews highlights installs as a central metric influencing user engagement (via reviews). However, its weak correlation with ratings and price indicates that while an app might be widely downloaded, its quality or cost does not heavily influence its success.

# %%
free_vs_paid = dfapps.groupby('Type')['Installs'].sum()

# %%
free_vs_paid.plot(kind='bar', title='Installs: Free vs Paid Apps (Log Scale)', color=['green', 'blue'])
plt.yscale('log')  # Apply log scale to the Y-axis
plt.ylabel('Total Installs (Log Scale)')
ax = free_vs_paid.plot(kind='bar', title='Installs: Free vs Paid Apps', color=['green', 'blue'])
for i, value in enumerate(free_vs_paid):
    ax.text(i, value, f'{value:,}', ha='center', va='bottom', fontsize=10)
plt.ylabel('Total Installs')
plt.show()

# %%
# Display dataset information
print(dfreviews.info())
print(dfreviews.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB
# None
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# ...

# %%
# Drop rows with missing sentiment or review
dfreviews.dropna(subset=['Translated_Review', 'Sentiment'], inplace=True)
print(dfreviews.head())
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000

# %%
# Sentiment count
sentiment_counts = dfreviews['Sentiment'].value_counts()
print(sentiment_counts)

# Plot sentiment distribution
import matplotlib.pyplot as plt

sentiment_counts.plot(kind='bar', color=['green', 'red', 'blue'], title='Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()
# Out:
# Sentiment
# Positive    23998
# Negative     8271
# Neutral      5158
# Name: count, dtype: int64

# %%
# Merge datasets
merged_df = pd.merge(dfapps, dfreviews, on='App', how='inner')

print(merged_df.info())
print(merged_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35929 entries, 0 to 35928
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     35929 non-null  object
#  1   Category                35929 non-null  object
#  2   Rating                  35929 non-null  float64
#  3   Reviews                 35929 non-null  int64
#  4   Size                    24069 non-null  float64
#  5   Installs                35929 non-null  int64
#  6   Type                    35929 non-null  object
#  7   Price                   35929 non-null  float64
#  8   Content Rating          35929 non-null  object
#  9   Genres                  35929 non-null  object
#  10  Last Updated            35929 non-null  object
#  11  Current Ver             35929 non-null  object
#  12  Android Ver             35929 non-null  object
#  13  Translated_Review       35929 non-null  object
# ...

# %%
sentiment_by_category = (
    merged_df.groupby('Category')['Sentiment_Polarity']
    .mean()
    .sort_values(ascending=False)
)
print(sentiment_by_category)
# Out:
# Category
# COMICS                 0.449810
# EVENTS                 0.377933
# AUTO_AND_VEHICLES      0.348683
# PARENTING              0.318880
# EDUCATION              0.310538
# WEATHER                0.294978
# HEALTH_AND_FITNESS     0.290823
# PERSONALIZATION        0.278490
# MAPS_AND_NAVIGATION    0.267218
# FOOD_AND_DRINK         0.266882
# BOOKS_AND_REFERENCE    0.248422
# ART_AND_DESIGN         0.245420
# LIBRARIES_AND_DEMO     0.240771
# HOUSE_AND_HOME         0.235704
# BUSINESS               0.232189
# MEDICAL                0.224071
# PHOTOGRAPHY            0.223078
# LIFESTYLE              0.215944
# TOOLS                  0.214037
# SHOPPING               0.196654
# TRAVEL_AND_LOCAL       0.194810
# BEAUTY                 0.193360
# PRODUCTIVITY           0.184225
# DATING                 0.178846
# COMMUNICATION          0.177275
# FINANCE                0.170783
# SPORTS                 0.167843
# VIDEO_PLAYERS          0.143543
# ENTERTAINMENT          0.127885
# ...

# %% [markdown]
# Avergae Sentiment Polarity by category

# %%
top_positive_apps = (
    merged_df.groupby('App')['Sentiment_Polarity']
    .mean()
    .sort_values(ascending=False)
    .head(10)
)
print(top_positive_apps)
# Out:
# App
# HomeWork                                              1.000000
# Google Slides                                         0.933333
# Daily Workouts - Exercise Fitness Routine Trainer     0.800000
# Bed Time Fan - White Noise Sleep Sounds               0.781250
# Cameringo Lite. Filters Camera                        0.770269
# Google Primer                                         0.750000
# GPS Map Free                                          0.700000
# GPS Speedometer and Odometer                          0.687500
# Best Ovulation Tracker Fertility Calendar App Glow    0.595313
# 3D Live Neon Weed Launcher                            0.568182
# Name: Sentiment_Polarity, dtype: float64

# %% [markdown]
# Top 10 apps which have the most positive reviews on average. Homework being the highest

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
# Filter reviews with positive sentiment
positive_reviews = dfreviews[dfreviews['Sentiment'] == 'Positive']['Translated_Review']

# %%
# Combine all positive reviews into a single string
all_positive_reviews = ' '.join(review for review in positive_reviews if pd.notnull(review))

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt


# Add custom stopwords
custom_stopwords = set(STOPWORDS)
custom_stopwords.update(["app", "apps", "use", "using"])  # Add any words you want to exclude

# Generate the word cloud again, excluding stopwords
wordcloud = WordCloud(
    background_color='white',
    max_words=200,
    width=800,
    height=400,
    colormap='viridis',
    stopwords=custom_stopwords
).generate(all_positive_reviews)

# Display the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Common Words in Positive Reviews (Without Stop Words)')
plt.show()

# %% [markdown]
# This is a word cloud which shows the words that indicate positive reviews. Words like "great", "easy", "love", "best" often indicate why users like these apps

# %%
negative_reviews = dfreviews[dfreviews['Sentiment'] == 'Negative']['Translated_Review']
all_negative_reviews = ' '.join(review for review in negative_reviews if pd.notnull(review))
wordcloud_negative = WordCloud(
    background_color='white',
    max_words=200,
    width=800,
    height=400,
    colormap='coolwarm',
    stopwords=custom_stopwords
).generate(all_negative_reviews)

plt.figure(figsize=(12, 8))
plt.imshow(wordcloud_negative, interpolation='bilinear')
plt.axis('off')
plt.title('Common Words in Negative Reviews', fontsize=16)
plt.show()

# %% [markdown]
# Keywords like 'bad','update','want','hate','frustrating' indicate negative reviews

# %%
# Merge apps and reviews datasets
merged_df = pd.merge(dfapps, dfreviews, on='App', how='inner')

# Calculate correlation between Sentiment Polarity and Ratings
correlation = merged_df[['Rating', 'Sentiment_Polarity']].corr()
print(correlation)
# Out:
#                       Rating  Sentiment_Polarity
# Rating              1.000000            0.093644
# Sentiment_Polarity  0.093644            1.000000

# %% [markdown]
# A correlation of 0.0936 suggests that higher ratings tend to slightly align with more positive sentiment in user reviews, but the relationship is not strong.
# This could imply that ratings and review sentiments are influenced by different factors.
# <br>1)Bias in Ratings: Some users might give high ratings but leave neutral or even negative comments.
# <br>2)Subjectivity in Sentiment Analysis: Sentiment polarity scores are derived from text, which may not fully capture the user's overall sentiment.
# Feature Limitations: Ratings may be influenced by factors not reflected in textual reviews, such as app performance, pricing, or specific features.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(data=merged_df, x='Rating', y='Sentiment_Polarity', alpha=0.5)
plt.title('Ratings vs Sentiment Polarity')
plt.xlabel('Rating')
plt.ylabel('Sentiment Polarity')
plt.show()

# %% [markdown]
# For most ratings (especially in the range of 3.0 to 5.0), the sentiment polarity values are widely spread across positive, neutral, and negative sentiments.
# This indicates that user ratings do not always align with the sentiment of their reviews
# <br>There is a noticeable density of points around Rating = 4.0 to 5.0.
# These ratings are associated with a mix of sentiments, but the majority seem to fall into the positive or neutral sentiment polarity range.
# <br>A significant portion of data points, regardless of rating, have sentiment polarity close to 0.0 (neutral). This suggests that many reviews may not express strong emotions.
